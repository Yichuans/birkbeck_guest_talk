# %% [markdown]
# # Geospatial example using ArcPy: WDPA change statistics
#
# ## The background
#
# After countries submit spatial data to UNEP-WCMC, we incorporate them in World Database on Protected Areas (WDPA), which is released to the public on a monthly basis. It is imperative that quality control is in place to ensure:
#
# 1. There are no inherent quality issues in the newly submitted data
# 2. Update is correctly incorporated as intended (it could introduce serious errors too, if one is not careful!)
#
# Furthermore, it is often useful for data curators to keep a record of what happened during an update, in case any retrospective examinations require this information in the future.
#
# ## What needs to be done
#
# For any two given WDPA releases with the same schema, a pair-wise comparison is calculated for each of the required fields, for example: `name`, `orig_name`, `desig` and etc. If there is a difference, record both the old and new values. It is also necessary to flag records that have been added or deleted.
#
# Geometric changes are a must as they, in theory, indicate a change in protected areas boundary. However, it is also possible that the difference may reflect the fact that a better boundary (or mapped at a larger scale) is provided. Thus the check should provide an indication of these differences but defer the judgement to programme staff.
#
# ## Challenges
#
# 1. Must be automated as it is not feasible to undertake examination each time when an update is ready for release
# 1. Differences must be identified at the field level
# 2. The large size of WDPA datasets
#
# ## Solution
#
# A production ready solution can be found [here](https://github.com/Yichuans/geoprocessing/blob/master/snippet/check_wdpa_update.py)

# %%
import numpy as np
import pandas as pd
import arcpy

# %%
# old_data_path = r"..\..\WDPA\WDPA_May2016_Public\WDPA_May2016_Public.gdb\WDPA_poly_May2016"
# new_data_path = r"..\..\WDPA\WDPA_Oct2016_Public\WDPA_Oct2016_Public.gdb\WDPA_poly_Oct2016"
# old_data_path = r"..\..\WDPA\WDPA_Dec2016_Public\WDPA_Dec2016_Public.gdb\WDPA_poly_Dec2016"
# new_data_path = r"..\..\WDPA\WDPA_Jan2017_Public\WDPA_Jan2017_Public.gdb\WDPA_poly_Jan2017"
# old_data_path = r".\Yichuan.gdb\Old__HUN"
# new_data_path = r".\Yichuan.gdb\New__HUN"

old_data_path = r".\Yichuan.gdb\Old__AUT"
new_data_path = r".\Yichuan.gdb\New__AUT"

# out_file = 'test_out_hun.csv'
out_file = 'test_wdpa.csv'

# %% [markdown]
# Create a function that finds a corresponding row in the second dataset

# %%
def get_row_info(wdpa_pid, data, fields_list):
    """"
    depending on the datatype of pid, generate correct SQL
    <wdpa_pid>, <fc/fl>, <list of fields>"""
    where_name = (isinstance(wdpa_pid, int) or isinstance(wdpa_pid, float)) and str(wdpa_pid) or ('\'' + str(wdpa_pid) + '\'')
    
    where_clause = "wdpa_pid = " + where_name
#     print(where_clause)

    with arcpy.da.SearchCursor(data, fields_list, where_clause=where_clause) as cur:
        for each in cur:
            # if found return the first value
            return each
    # if not found return None
    return None

# %% [markdown]
# It can be annoying having to create a layer with a name that has been used before
#
# Create a wrap for a function that does 1) checking if the layer name has been used, if used delete 2) create the layer

# %%
def create_layer(data, out_layer, *arg, **karg):
    if arcpy.Exists(out_layer):
        arcpy.Delete_management(out_layer)
    arcpy.MakeFeatureLayer_management(data, out_layer, *arg, **karg)

# %% [markdown]
# Create layers, which make things run a lot faster!

# %%
# create layers
old_data = 'old'
new_data = 'new'

# create layers for two monthly releases
create_layer(old_data_path, old_data)
create_layer(new_data_path, new_data)

# %% [markdown]
# Run a few spot checks to see if the `get_row_info` function works

# %%
with arcpy.da.SearchCursor(old_data, ['wdpaid', 'name', 'desig']) as cur:
    for i, row in enumerate(cur):
        print i, row[0], row[1], row[2]
# Out:
# 0 67802.0 Donau-March-Thaya-Auen Ramsar Site, Wetland of International Importance
# 1 67805.0 Rheindelta Ramsar Site, Wetland of International Importance
# 2 902719.0 Bayerische Wildalm and Wildalmfilz Ramsar Site, Wetland of International Importance
# 3 555558378.0 Wilder Kaiser Ramsar Site, Wetland of International Importance
# 4 67807.0 Sablatnigmoor Ramsar Site, Wetland of International Importance
# 5 95319.0 Rotmoos im Fuschertal Ramsar Site, Wetland of International Importance
# 6 67801.0 Neusiedlersee, Seewinkel & Hanság Ramsar Site, Wetland of International Importance
# 7 67803.0 Untere Lobau Ramsar Site, Wetland of International Importance
# 8 67804.0 Stauseen am Unteren Inn Ramsar Site, Wetland of International Importance
# 9 67806.0 Pürgschachen Moor Ramsar Site, Wetland of International Importance
# 10 555558377.0 Güssing Fishponds Ramsar Site, Wetland of International Importance
# 11 1218.0 Neusiedler See und Umgebung Landschafts- und Naturschutzgebiet
# 12 4341.0 Landschaftssee in der KG Laafeld Naturschutzgebiet
# 13 4342.0 Verlandungszone am Ostende des Packer Stausees Naturschutzgebiet
# 14 4343.0 Kaisergebirge Naturschutzgebiet
# 15 4346.0 Lainzer Tiergarten Naturschutzgebiet
# 16 4349.0 Rheindelta Naturschutzgebiet
# 17 4352.0 Wegscheider Teich Naturschutzgebiet
# 18 4354.0 Auwald und Moorgebiet Greith Naturschutzgebiet
# 19 5419.0 Bangser Ried Naturschutzgebiet
# 20 5423.0 Niedere Tauern Landschaftsschutzgebiet
# 21 5425.0 Blockheide-Eibenstein Naturschutzgebiet
# 22 5427.0 Pleschkogel-Walzkogel-Mühlbachgraben Naturschutzgebiet
# 23 5434.0 Ahrnspitze Naturschutzgebiet
# 24 5439.0 Valsertal Naturschutzgebiet
# 25 5441.0 Antelsberg bei Tarrenz Naturschutzgebiet
# 26 5442.0 Kufsteiner und Langkampfener Innauen Naturschutzgebiet
# 27 5443.0 Vilsalpsee Naturschutzgebiet
# 28 5447.0 Trumerseen Naturschutzgebiet
# 29 5448.0 Egelseen Naturschutzgebiet
# 30 5452.0 Obertrumer See Naturschutzgebiet
# 31 5453.0 Fischlhamerau Naturschutzgebiet
# 32 5456.0 Mürzaugebiet zwischen Krieglach und Langenwang Naturschutzgebiet
# 33 5546.0 Eichkogel Naturschutzgebiet
# 34 5547.0 Sandberge Oberweiden Naturschutzgebiet
# 35 5549.0 Pischelsdorfer Wiesen Naturschutzgebiet
# 36 5550.0 Geras und seine Umgebung Landschaftsschutzgebiet
# 37 5551.0 Salzsteppe Baumgarten an der March Naturschutzgebiet
# 38 5552.0 Insel Wörth Naturschutzgebiet
# 39 5553.0 Falkenstein Landschaftsschutzgebiet
# 40 5555.0 Lechnergraben Naturschutzgebiet
# 41 5561.0 Bernstein - Lockenhaus - Rechnitz Landschaftsschutzgebiet
# 42 5563.0 Zurndorfer Eichenwald und Hutweide Naturschutzgebiet
# 1514 555577606.0 Flachwasserbiotop Neudenstein Special Protection Area (Birds Directive)
# 1515 555577610.0 Schütt - Graschelitzen Special Protection Area (Birds Directive)
# 1516 555577611.0 Untere Lavant Special Protection Area (Birds Directive)
# 1517 555577632.0 Raabklamm Special Protection Area (Birds Directive)
# 1518 555577638.0 Ettenau Special Protection Area (Birds Directive)
# 1519 555577650.0 Hohe Tauern, Salzburg Special Protection Area (Birds Directive)
# 1520 555577659.0 Bürmooser Moor Special Protection Area (Birds Directive)
# 1521 555577662.0 Valsertal Special Protection Area (Birds Directive)
# 1522 555577665.0 Tiroler Lech Special Protection Area (Birds Directive)
# 1523 555577598.0 Landschaftsschutzgebiet Liesing (Teil A, B und C) Special Protection Area (Birds Directive)
# 1524 555577579.0 Waasen - Hanság Special Protection Area (Birds Directive)
# 1525 555577580.0 Waldviertel Special Protection Area (Birds Directive)
# 1526 555577584.0 Wachau - Jauerling Special Protection Area (Birds Directive)
# 1527 555577588.0 Wienerwald - Thermenregion Special Protection Area (Birds Directive)
# 1528 555577589.0 Nordöstliche Randalpen Special Protection Area (Birds Directive)
# 1529 555577591.0 Tullnerfelder Donau-Auen Special Protection Area (Birds Directive)
# 1530 555577602.0 Stappitzer See und Umgebung Special Protection Area (Birds Directive)
# 1531 555577630.0 Ennstal zwischen Liezen und Niederstuttern Special Protection Area (Birds Directive)
# 1532 555577636.0 Pfeifer Anger Special Protection Area (Birds Directive)
# 1533 555577640.0 Oberes Donautal Special Protection Area (Birds Directive)
# 1534 555577651.0 Klemmerich Special Protection Area (Birds Directive)
# 1535 555577656.0 Kematen Special Protection Area (Birds Directive)
# 1536 555577575.0 Neusiedler See - Nordöstliches Leithagebirge Special Protection Area (Birds Directive)
# 1537 555577607.0 Obere Drau Special Protection Area (Birds Directive)
# 1538 555577612.0 Tiebelmündung Special Protection Area (Birds Directive)
# 1539 555577614.0 Lendspitz-Maiernigg Special Protection Area (Birds Directive)
# 1540 555577615.0 Guntschacher Au Special Protection Area (Birds Directive)
# 1541 555577618.0 Lafnitztal - Neudauer Teiche Special Protection Area (Birds Directive)
# 1542 555577631.0 Teile des südoststeirischen Hügellandes inklusive Höll und Grabenlandbäche Special Protection Area (Birds Directive)
# 1543 555577642.0 Traun-Donau-Auen Special Protection Area (Birds Directive)
# 1544 555577660.0 Hohe Tauern, Tirol Special Protection Area (Birds Directive)
# 1545 555577597.0 Naturschutzgebiet Lainzer Tiergarten Special Protection Area (Birds Directive)
# 1546 555577599.0 Bisamberg (Wiener Teil) Special Protection Area (Birds Directive)
# 1547 555577576.0 Auwiesen Zickenbachtal Special Protection Area (Birds Directive)
# 1548 555577585.0 Kamp- und Kremstal Special Protection Area (Birds Directive)
# 1549 555577604.0 Völkermarkter Stausee Special Protection Area (Birds Directive)
# 1550 555577613.0 Nationalpark Hohe Tauern, Kärnten II Special Protection Area (Birds Directive)
# 1551 555577644.0 Wiesengebiete im Freiwald Special Protection Area (Birds Directive)
# 1552 555577649.0 Salzachauen, Salzburg Special Protection Area (Birds Directive)
# 1553 555577654.0 Hochgimpling Special Protection Area (Birds Directive)
# 1554 555577666.0 Ortolanvorkommen Silz-Haiming-Stams Special Protection Area (Birds Directive)
# 1555 555577668.0 Lauteracher Ried Special Protection Area (Birds Directive)

# %%
# check if data is there
print get_row_info('191', old_data, ['wdpaid', 'name'])
# Out:
# None

# %%
# check if data is there
print get_row_info('4342', new_data, ['wdpaid', 'name'])
# Out:
# (4342.0, u'Verlandungszone am Ostende des Packer Stausees')

# %% [markdown]
# Get information about geometry

# %%
def geom_description(geom):
    if not isinstance(geom, arcpy.Geometry):
        raise Exception('arcpy Geometry object expected')
    
    try:
        return 'area:{0:.2f}km2; point_count:{1}; part_count:{2}; centroid(xy):{3:.6f}-{4:.6f}'.format(geom.getArea(units='SQUAREKILOMETERS'),
        geom.pointCount,
        geom.partCount,
        geom.centroid.X,
        geom.centroid.Y)

    except:
        return 'Error in retrieving geometry information'

# %%
# %%timeit about: 4min 13s for WDPA

from collections import deque
q = deque()

BASE = ['wdpa_pid', 'name', 'parent_iso3']
header = BASE + ['field', 'old_value', 'new_value']
fields_to_check = BASE + ['name', 'orig_name', 'desig', 'desig_eng', 'desig_type', 'iucn_cat', 'no_take', 'status', 'status_yr', 'SHAPE@']

FIELDS_LEN = len(fields_to_check)

o_idlist = list()

# header
q.append(header)

# start from old: DELETION and CHANGE
with arcpy.da.SearchCursor(old_data, fields_to_check) as cur:
    # for each old row, find and compare new row
    for o_row in cur:
        wdpa_pid = o_row[0]
        name = o_row[1]
        iso3 = o_row[2]
        n_row = get_row_info(wdpa_pid, new_data, fields_list=fields_to_check)
        
        # if no new row is found
        if not n_row:
            row = [wdpa_pid, name, iso3, 'DELETED', '', '']
            q.append(row)
        
        # if corresponding row found
        else:
            o_idlist.append(wdpa_pid)
            
            # Non spatial
            for i in range(FIELDS_LEN)[3:-1]:
                if n_row[i] != o_row[i]:
                    # row: pid, name, iso3, field, old_val, new_val
                    row = [wdpa_pid, name, iso3, fields_to_check[i], o_row[i], n_row[i]]
                    q.append(row)
            
            # spatial
            if n_row[-1] != o_row[-1]:
                row = [wdpa_pid, name, iso3, 'Geometry', geom_description(o_row[-1]), geom_description(n_row[-1])]
                q.append(row)

# %%
# start from new: ADD
n_idlist = list()
with arcpy.da.SearchCursor(new_data, BASE) as cur:
    for row in cur:
        n_idlist.append(row[0])

# %%
len(n_idlist), len(o_idlist)
# Out:
# (1438, 1438)

# %%
# find addition
import numpy as np
n_id = np.array(n_idlist)
o_id = np.array(o_idlist)

np.setdiff1d(o_id, n_id)

a_id = list(np.setdiff1d(n_id, o_id))

for wdpa_pid in a_id:
    n_row = get_row_info(wdpa_pid, new_data, BASE)

    wdpa_pid = n_row[0]
    name = n_row[1]
    iso3 = n_row[2]
    
    row = [wdpa_pid, name, iso3, 'ADDED', '', '']
    q.append(row)

# %%
# write outputs
import codecs
import copy

# shallow copy
qq = copy.deepcopy(q)

with codecs.open(out_file, mode='w', encoding='utf-8') as f:
    while qq:
        row = qq.popleft()
        # convert int and float to str, noting unicode
        # and-or trick: C equivalent boolean? x, y
        f.write(','.join(map(lambda x: (isinstance(x, int) or isinstance(x, float)) and str(x) or "\"" + x + "\"", row)) + '\n')

# %% [markdown]
# Take a look at the output file

# %%
result = pd.read_csv(out_file)

# %%
result
# Out:
#       wdpa_pid                              name parent_iso3      field  \
# 0       169099                       Hohe Tauern         AUT   Geometry
# 1       169489         Teile des Edlacher Moores         AUT      desig
# 2       169489         Teile des Edlacher Moores         AUT  desig_eng
# 3       169489         Teile des Edlacher Moores         AUT   Geometry
# 4    555513711        Naturpark Rosalia-Koglberg         AUT   Geometry
# 5    555513732             südlich Neuberggipfel         AUT  desig_eng
# 6    555513733                       Fasangarten         AUT  desig_eng
# 7    555558910       Nähe Herrnholz-Stammersdorf         AUT  desig_eng
# 8         4348                  Inneres Pöllatal         AUT    DELETED
# 9         5420                            Mussen         AUT    DELETED
# 10        5457              Grünsee und Umgebung         AUT    DELETED
# 11        5459                      Jammernspitz         AUT    DELETED
# 12        5460                     Tiebelmündung         AUT    DELETED
# 13        5461                         Meerspitz         AUT    DELETED
# 14        5463                    Spintik-Teiche         AUT    DELETED
# 15        5465                  Hallegger Teiche         AUT    DELETED
# 16        5467   Inneres Bodental und Vertatscha         AUT    DELETED
# 17        5468                Vellacher Kotschna         AUT    DELETED
# 18        5469            Flattnitzbach-Hochmoor         AUT    DELETED
# 19        5470                        Bretterich         AUT    DELETED
# 20        5473                         Weißensee         AUT    DELETED
# 21        5474                       Danielsberg         AUT    DELETED
# 22        5475             Millstätter See - Süd         AUT    DELETED
# 23        5476                     Farchtner See         AUT    DELETED
# 24        5477                      Afritzer See         AUT    DELETED
# 25        5480            Wollanig - Oswaldiberg         AUT    DELETED
# 26        5481                     Vassacher See         AUT    DELETED
# 27        5482                Ossiacher See-West         AUT    DELETED
# 28        5483                   Ruine Landskron         AUT    DELETED
# 29        5484                   Faaker See-West         AUT    DELETED
# ..         ...                               ...         ...        ...
# 96      102839                 Gösselsdorfer See         AUT    DELETED
# 97      103599                   Strussnig Teich         AUT    DELETED
# 98      103602                      Höflein Moor         AUT    DELETED
# 99      103605                Gut Walterskirchen         AUT    DELETED
# 100     106614                      Kleinfragant         AUT    DELETED
# 101     106615                       Wurten-West         AUT    DELETED
# 102     106616                          Auenmoos         AUT    DELETED
# 103     106619                     Innere Wimitz         AUT    DELETED
# 104     106620                        Türkenmoos         AUT    DELETED
# 105     106623                 Drobollacher Moor         AUT    DELETED
# 106     106624                Finkensteiner Moor         AUT    DELETED
# 107     106625                 Kaltschacher Moor         AUT    DELETED
# 108     106626     Flachwasserbiotop Neudenstein         AUT    DELETED
# 109     106627             Gösselsdorfer See Süd         AUT    DELETED
# 110     106629                    Trögener Klamm         AUT    DELETED
# 111     106631             Völkermarkter Stausee         AUT    DELETED
# 112     106632                Großedlinger Teich         AUT    DELETED
# 113     106633  Koralpe - großes und kleines Kar         AUT    DELETED
# 114     106634          Lavantteich bei St. Paul         AUT    DELETED
# 115     169106                           Egelsee         AUT    DELETED
# 116     169107                           Hörfeld         AUT    DELETED
# 117     169137           Ossiacher See-Westbucht         AUT    DELETED
# 118     169146       Sablatnigmoor bei Eberndorf         AUT    DELETED
# 119     169177                    Pirkdorfer See         AUT    DELETED
# 120     169186        Villacher Alpe (Dobratsch)         AUT    DELETED
# 121     387314                         Dobratsch         AUT    DELETED
# 122     387315                         Weißensee         AUT    DELETED
# 123     387316       Flachwasserbiotop Föderlach         AUT    DELETED
# 124     387317                   Guntschacher Au         AUT    DELETED
# 125  555559232                         Nockberge         AUT    DELETED
#
#                                              old_value  \
# 0    area:805.59km2; point_count:6734; part_count:4...
# 1                          Geschützter Landschaftsteil
# 2                          Protected Landscape Section
# 3    area:0.18km2; point_count:80; part_count:1; ce...
# 4    area:505.86km2; point_count:3818; part_count:1...
# 5                                    Protected Biotope
# 6                                    Protected Biotope
# 7                                    Protected Biotope
# 8                                                  NaN
# 9                                                  NaN
# 10                                                 NaN
# 11                                                 NaN
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# ..                                                 ...
# 96                                                 NaN
# 97                                                 NaN
# 98                                                 NaN
# 99                                                 NaN
# 100                                                NaN
# 101                                                NaN
# 102                                                NaN
# 103                                                NaN
# 104                                                NaN
# 105                                                NaN
# 106                                                NaN
# 107                                                NaN
# 108                                                NaN
# 109                                                NaN
# 110                                                NaN
# 111                                                NaN
# 112                                                NaN
# 113                                                NaN
# 114                                                NaN
# 115                                                NaN
# 116                                                NaN
# 117                                                NaN
# 118                                                NaN
# 119                                                NaN
# 120                                                NaN
# 121                                                NaN
# 122                                                NaN
# 123                                                NaN
# 124                                                NaN
# 125                                                NaN
#
#                                              new_value
# 0             Error in retrieving geometry information
# 1                                    Naturschutzgebiet
# 2                                       Nature Reserve
# 3    area:0.18km2; point_count:80; part_count:1; ce...
# 4    area:577.98km2; point_count:12095; part_count:...
# 5                                   protected biotopes
# 6                                   protected biotopes
# 7                                   protected biotopes
# 8                                                  NaN
# 9                                                  NaN
# 10                                                 NaN
# 11                                                 NaN
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# ..                                                 ...
# 96                                                 NaN
# 97                                                 NaN
# 98                                                 NaN
# 99                                                 NaN
# 100                                                NaN
# 101                                                NaN
# 102                                                NaN
# 103                                                NaN
# 104                                                NaN
# 105                                                NaN
# 106                                                NaN
# 107                                                NaN
# 108                                                NaN
# 109                                                NaN
# 110                                                NaN
# 111                                                NaN
# 112                                                NaN
# 113                                                NaN
# 114                                                NaN
# 115                                                NaN
# 116                                                NaN
# 117                                                NaN
# 118                                                NaN
# 119                                                NaN
# 120                                                NaN
# 121                                                NaN
# 122                                                NaN
# 123                                                NaN
# 124                                                NaN
# 125                                                NaN
#
# [126 rows x 6 columns]

# %% [markdown]
# # Testing

# %%
a = get_row_info(wdpa_pid='9566', fields_list=['SHAPE@'], data=old_data)
b = get_row_info(wdpa_pid='9566', fields_list=['SHAPE@'], data=new_data)

# %%
a[0]!=b[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-9f361f4b49c8> in <module>()
# ----> 1 a[0]!=b[0]
#
# TypeError: 'NoneType' object has no attribute '__getitem__'

# %%
type(a[0])
# Out:
# arcpy.arcobjects.geometries.Polygon

# %%
isinstance(a[0], arcpy.Geometry)
# Out:
# True

# %%
geom = a[0]

# %%
geom.area
# Out:
# 0.028423471395934402

# %%
geom.getArea()
# Out:
# 237276902.62753934

# %%
geom_description(geom)
# Out:
# 'area:237.28km2; point_count:5133; part_count:10; centroid(xy):16.732991-47.673819'

# %%
geom_description(b[0])
# Out:
# 'area:237.28km2; point_count:5133; part_count:10; centroid(xy):16.732991-47.673819'

# %%
geom.getArea(units='SQUAREKILOMETERS')
# Out:
# 237.27690262753933

# %%
geom.partCount
# Out:
# 10

# %%
geom.centroid.X
# Out:
# 16.732990895000057

# %%
b[0].centroid.X
# Out:
# 16.732990895000057

# %%
geom.pointCount
# Out:
# 5133

# %%
b[0].pointCount
# Out:
# 5133

# %%
aa = range(10)
aa[3:-1]
# Out:
# [3, 4, 5, 6, 7, 8]

# %%
# %%timeit
# get_row_info(wdpaid=191, data=old_data, fields_list=['wdpaid', 'name', 'status_yr'])
# get_row_info(wdpaid=191, data=new_data, fields_list=['wdpaid', 'name', 'status_yr'])

# %%
# from collections import deque
# queue = deque(["Eric", "John", "Michael"])
# queue.append("Terry")           # Terry arrives
# queue.append("Graham")          # Graham arrives
# queue.popleft()                 # The first to arrive now leaves

# %%
# %%timeit
# q2 = deque(range(1000))
# while q2:
#     q2.popleft()

# %%
# %%timeit
# q3 = deque(range(1000))
# while q2:
#     q2.pop()

# %%
# %%timeit
# s2 = range(1000)
# while s2:
#     s2.pop()

# %%
# # testing performance
# fields = ['name', 'status_yr']
# n_row = get_row_info(191, new_data, fields)
# o_row = get_row_info(191, old_data, fields)
# print(n_row, o_row)
